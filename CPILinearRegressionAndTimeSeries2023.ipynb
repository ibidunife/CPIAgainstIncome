# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('CPI_IncomePercentageIncrease_2017_2022.xlsx', sheet_name='PythonPrediction')
df.head()
# Out:
#    Year Quarters       Income         CPI
# 0  2017       Q1  1014.274524  130.340476
# 1  2017       Q2  1015.336190  131.009524
# 2  2017       Q3  1024.416190  131.161905
# 3  2017       Q4  1029.538095  131.842857
# 4  2018       Q1  1034.383333  133.047619

# %%
df
# Out:
#     Year Quarters       Income         CPI
# 0   2017       Q1  1014.274524  130.340476
# 1   2017       Q2  1015.336190  131.009524
# 2   2017       Q3  1024.416190  131.161905
# 3   2017       Q4  1029.538095  131.842857
# 4   2018       Q1  1034.383333  133.047619
# 5   2018       Q2  1037.382857  134.119048
# 6   2018       Q3  1046.671429  134.816667
# 7   2018       Q4  1051.705476  134.473810
# 8   2019       Q1  1055.856667  134.961905
# 9   2019       Q2  1072.330952  136.745238
# 10  2019       Q3  1075.320952  137.147619
# 11  2019       Q4  1090.103333  137.050000
# 12  2020       Q1  1095.482381  137.576190
# 13  2020       Q2  1161.802143  136.435714
# 14  2020       Q3  1139.885000  137.028571
# 15  2020       Q4  1140.639286  137.569048
# 16  2021       Q1  1147.211429  139.085714
# 17  2021       Q2  1149.010000  140.980952
# 18  2021       Q3  1165.124524  142.707143
# 19  2021       Q4  1167.476667  143.890476
# 20  2022       Q1  1188.505238  146.821429
# 21  2022       Q2  1189.665476  151.676190
# 22  2022       Q3  1204.670476  153.071429
# 23  2022       Q4  1207.002619  154.651270

# %%
sns.pairplot(df)

# %%
from statsmodels.tsa.filters.hp_filter import hpfilter
import matplotlib.pyplot as plt
CPI_cycle,CPI_trend = hpfilter(df['CPI'], lamb=1600)
CPI_trend.plot(figsize=(15,6)).autoscale(axis='x',tight=True)
plt.title('CPI Trend', fontsize=16)
# Out:
# Text(0.5, 1.0, 'CPI Trend')

# %%
from statsmodels.tsa.filters.hp_filter import hpfilter
import matplotlib.pyplot as plt
Income_cycle,Income_trend = hpfilter(df['Income'], lamb=1600)
Income_trend.plot(figsize=(15,6)).autoscale(axis='x',tight=True)
plt.title('Income Trend', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Income Trend')

# %%
from statsmodels.tsa.filters.hp_filter import hpfilter
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
CPI_cycle,CPI_trend = hpfilter(df['CPI'], lamb=1600)
df['cycle'] =CPI_cycle
df['trend'] =CPI_trend
df[['cycle']].plot(figsize=(15,6)).autoscale(axis='x',tight=True)
plt.title('Extracting Cyclic Variations For CPI', fontsize=16)
plt.xlabel('Year')
plt.ylabel('CPI')
plt.show()

# %%
df
# Out:
#     Year Quarters       Income         CPI     cycle       trend
# 0   2017       Q1  1014.274524  130.340476  1.065004  129.275472
# 1   2017       Q2  1015.336190  131.009524  1.017242  129.992282
# 2   2017       Q3  1024.416190  131.161905  0.452147  130.709757
# 3   2017       Q4  1029.538095  131.842857  0.413657  131.429200
# 4   2018       Q1  1034.383333  133.047619  0.895426  132.152193
# 5   2018       Q2  1037.382857  134.119048  1.238467  132.880581
# 6   2018       Q3  1046.671429  134.816667  1.199903  133.616763
# 7   2018       Q4  1051.705476  134.473810  0.109891  134.363918
# 8   2019       Q1  1055.856667  134.961905 -0.164066  135.125971
# 9   2019       Q2  1072.330952  136.745238  0.838321  135.906917
# 10  2019       Q3  1075.320952  137.147619  0.436971  136.710648
# 11  2019       Q4  1090.103333  137.050000 -0.491580  137.541580
# 12  2020       Q1  1095.482381  137.576190 -0.828213  138.404404
# 13  2020       Q2  1161.802143  136.435714 -2.867786  139.303500
# 14  2020       Q3  1139.885000  137.028571 -3.214162  140.242734
# 15  2020       Q4  1140.639286  137.569048 -3.655129  141.224177
# 16  2021       Q1  1147.211429  139.085714 -3.162179  142.247893
# 17  2021       Q2  1149.010000  140.980952 -2.330708  143.311661
# 18  2021       Q3  1165.124524  142.707143 -1.704140  144.411282
# 19  2021       Q4  1167.476667  143.890476 -1.650628  145.541104
# 20  2022       Q1  1188.505238  146.821429  0.127023  146.694406
# 21  2022       Q2  1189.665476  151.676190  3.812753  147.863438
# 22  2022       Q3  1204.670476  153.071429  4.030902  149.040527
# 23  2022       Q4  1207.002619  154.651270  4.430884  150.220386

# %%
from statsmodels.tsa.filters.hp_filter import hpfilter
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
Income_cycle,Income_trend = hpfilter(df['Income'], lamb=1600)
df['cycleIncome'] =Income_cycle
df['trendIncome'] =Income_trend
df[['cycleIncome']].plot(figsize=(15,6)).autoscale(axis='x',tight=True)
plt.title('Extracting Cyclic Variations For Income', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Income')
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'figure.figsize':(15,6), 'figure.dpi':220})
autocorrelation_plot(df.CPI.tolist())
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
from pandas.plotting import autocorrelation_plot
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'figure.figsize':(15,6), 'figure.dpi':220})
autocorrelation_plot(df.Income.tolist())
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
from statsmodels.tsa.api import SimpleExpSmoothing
import pandas as pd
import numpy as np
from sklearn import metrics

X = df['CPI']
test = X.iloc[-24:]
train = X.iloc[:-24]

def timeseries_evaluation_metrics_func(y_true, y_pred):
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')
    
resu = []
temp_df = pd.DataFrame()
for i in df.Income:
    print(f'Fitting for smoothing level= {i}')
    fit_v = SimpleExpSmoothing(np.asarray(train)).fit(i)
    fcst_pred_v= fit_v.forecast(24)
    timeseries_evaluation_metrics_func(test,fcst_pred_v)
    rmse = np.sqrt(metrics.mean_squared_error(test, fcst_pred_v))
    df3 = {'smoothing parameter':i, 'RMSE': rmse}
    temp_df = temp_df.append(df3, ignore_index=True)
temp_df.sort_values(by=['RMSE']).head(3)
# Out:
# Fitting for smoothing level= 1014.2745238095241
# Evaluation metric results:-
# MSE is : 61840676.21660051
# MAE is : 7863.878726750506
# RMSE is : 7863.884295728194
# MAPE is : 5504.398749426766
# R2 is : -706043.0461774835
#
# Fitting for smoothing level= 1015.3361904761902
# Evaluation metric results:-
# MSE is : 9287751.355994968
# MAE is : 3047.566860371337
# RMSE is : 3047.5812304178157
# MAPE is : 2132.9244378463004
# R2 is : -106038.61580738318
#
# Fitting for smoothing level= 1024.4161904761906
# Evaluation metric results:-
# MSE is : 21594600.032543007
# MAE is : 4646.989611025793
# RMSE is : 4646.999035134719
# MAPE is : 3252.5389617377527
# R2 is : -246547.70734528368
#
# Fitting for smoothing level= 1029.5380952380951
# Evaluation metric results:-
# MSE is : 66978175.32672637
# MAE is : 8184.014158050132
# RMSE is : 8184.0195091853475
# MAPE is : 5728.497273940471
# R2 is : -764698.6250110922
#
# Fitting for smoothing level= 1034.3833333333332
# Evaluation metric results:-
# MSE is : 21755063.17443918
# MAE is : 4664.222934946166
# RMSE is : 4664.232324235059
# MAPE is : 3264.602488874828
# R2 is : -248379.7385082339
#
# Fitting for smoothing level= 1037.3828571428571
# Evaluation metric results:-
# MSE is : 26691894.32620571
# MAE is : 5166.411398509062
# RMSE is : 5166.419875136526
# MAPE is : 3616.140252924817
# R2 is : -304744.26190832903
#
# Fitting for smoothing level= 1046.6714285714286
# Evaluation metric results:-
# MSE is : 42486484.92283455
# MAE is : 6518.159044950745
# RMSE is : 6518.165763681877
# MAPE is : 4562.379323847703
# R2 is : -485073.41312105634
#
# Fitting for smoothing level= 1051.7054761904765
# Evaluation metric results:-
# MSE is : 61223023.43956959
# MAE is : 7824.5086652139535
# RMSE is : 7824.514262212677
# MAPE is : 5476.839248547597
# R2 is : -698991.2140742859
#
# Fitting for smoothing level= 1055.8566666666663
# Evaluation metric results:-
# MSE is : 82214479.25578989
# MAE is : 9067.215210208067
# RMSE is : 9067.220040110966
# MAPE is : 6346.748280503696
# R2 is : -938653.7356762334
#
# Fitting for smoothing level= 1072.3309523809523
# Evaluation metric results:-
# MSE is : 30386100.914711725
# MAE is : 5512.35098004022
# RMSE is : 5512.358924699273
# MAPE is : 3858.3019826568298
# R2 is : -346921.5589034117
#
# Fitting for smoothing level= 1075.3209523809523
# Evaluation metric results:-
# MSE is : 96989932.94361766
# MAE is : 9848.3422643639
# RMSE is : 9848.346711180393
# MAPE is : 6893.546301526943
# R2 is : -1107347.2517258127
#
# Fitting for smoothing level= 1090.1033333333332
# Evaluation metric results:-
# MSE is : 94216083.68255566
# MAE is : 9706.492471278916
# RMSE is : 9706.496983080748
# MAPE is : 6794.249796907411
# R2 is : -1075677.8089644331
#
# Fitting for smoothing level= 1095.482380952381
# Evaluation metric results:-
# MSE is : 42879644.836848624
# MAE is : 6548.248410780342
# RMSE is : 6548.255098638768
# MAPE is : 4583.442229814068
# R2 is : -489562.17736925144
#
# Fitting for smoothing level= 1161.802142857143
# Evaluation metric results:-
# MSE is : 24208254.649586383
# MAE is : 4920.179576196892
# RMSE is : 4920.1884770389015
# MAPE is : 3443.7751140694663
# R2 is : -276388.18442325585
#
# Fitting for smoothing level= 1139.885
# Evaluation metric results:-
# MSE is : 37559756.93158123
# MAE is : 6128.594401983205
# RMSE is : 6128.601547790591
# MAPE is : 4289.679543828582
# R2 is : -428824.23898239125
#
# Fitting for smoothing level= 1140.6392857142855
# Evaluation metric results:-
# MSE is : 151635960.07837734
# MAE is : 12314.051830766994
# RMSE is : 12314.055387173526
# MAPE is : 8619.571669812716
# R2 is : -1731248.9369307552
#
# Fitting for smoothing level= 1147.2114285714285
# Evaluation metric results:-
# MSE is : 25138154.284856018
# MAE is : 5013.787659773264
# RMSE is : 5013.79639443566
# MAPE is : 3509.301861067948
# R2 is : -287004.9845812155
#
# Fitting for smoothing level= 1149.01
# Evaluation metric results:-
# MSE is : 118731716.47911519
# MAE is : 10896.404401982969
# RMSE is : 10896.40842108606
# MAPE is : 7627.2019849532835
# R2 is : -1355576.374653756
#
# Fitting for smoothing level= 1165.1245238095241
# Evaluation metric results:-
# MSE is : 5092681.53743754
# MAE is : 2256.677635347189
# RMSE is : 2256.6970415714954
# MAPE is : 1579.2927836986
# R2 is : -58142.890050486705
#
# Fitting for smoothing level= 1167.4766666666667
# Evaluation metric results:-
# MSE is : 53855896.40287042
# MAE is : 7338.651702820421
# RMSE is : 7338.657670369317
# MAPE is : 5136.733725222385
# R2 is : -614879.647061726
#
# Fitting for smoothing level= 1188.5052380952382
# Evaluation metric results:-
# MSE is : 97160055.4488209
# MAE is : 9856.975594027792
# RMSE is : 9856.980036949497
# MAPE is : 6899.58973268189
# R2 is : -1109289.5652525737
#
# Fitting for smoothing level= 1189.665476190476
# Evaluation metric results:-
# MSE is : 206202977.06458282
# MAE is : 14359.766344792015
# RMSE is : 14359.769394547491
# MAPE is : 10051.59561764062
# R2 is : -2354248.551712359
#
# Fitting for smoothing level= 1204.6704761904762
# Evaluation metric results:-
# MSE is : 244954306.49283168
# MAE is : 15651.013350747302
# RMSE is : 15651.016148890514
# MAPE is : 10955.483536708509
# R2 is : -2796678.1481877747
#
# Fitting for smoothing level= 1207.0026190476187
# Evaluation metric results:-
# MSE is : 2372294.1178260255
# MAE is : 1540.1969128214307
# RMSE is : 1540.2253464431838
# MAPE is : 1078.5635508970752
# R2 is : -27083.828953136654
#
# Fitting for smoothing level= 1215.5200000000002
# Evaluation metric results:-
# MSE is : 229520973.86643806
# MAE is : 15149.946741783506
# RMSE is : 15149.949632471986
# MAPE is : 10604.731083923054
# R2 is : -2620473.532064628
#
# Fitting for smoothing level= 1224.61
# Evaluation metric results:-
# MSE is : 67440859.58433159
# MAE is : 8212.233070046796
# RMSE is : 8212.238402794428
# MAPE is : 5748.250840473744
# R2 is : -769981.1588598168
#
# Fitting for smoothing level= 1233.7
# Evaluation metric results:-
# MSE is : 240622.44259044388
# MAE is : 490.4435288889895
# RMSE is : 490.53281499859304
# MAPE is : 342.9083710260379
# R2 is : -2746.221624366083
#
# Fitting for smoothing level= 1245.79
# Evaluation metric results:-
# MSE is : 320412858.4640563
# MAE is : 17900.077398617443
# RMSE is : 17900.07984518662
# MAPE is : 12529.854522820313
# R2 is : -3658199.4738254733
#     smoothing parameter         RMSE
# 26          1233.700000   490.532815
# 23          1207.002619  1540.225346
# 18          1165.124524  2256.697042
